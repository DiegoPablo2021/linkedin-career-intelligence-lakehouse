# %% [markdown]
# # Export Exploration
#
# Notebook inicial para entender a estrutura dos exports do LinkedIn e validar rapidamente quantidade de arquivos, tabelas e colunas mais relevantes.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = next(parent for parent in [Path.cwd(), *Path.cwd().parents] if (parent / 'linkedin_career_intelligence').exists())
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd

from linkedin_career_intelligence.config import get_settings

settings = get_settings()
settings
# Out:
# ProjectSettings(project_root=WindowsPath('C:/Projetos/linkedIn_career_intelligence_lakehouse'), data_dir=WindowsPath('C:/Projetos/linkedIn_career_intelligence_lakehouse/data'), raw_dir=WindowsPath('C:/Projetos/linkedIn_career_intelligence_lakehouse/data/raw'), warehouse_dir=WindowsPath('C:/Projetos/linkedIn_career_intelligence_lakehouse/warehouse'), demo_dir=WindowsPath('C:/Projetos/linkedIn_career_intelligence_lakehouse/demo'), db_path=WindowsPath('C:/Projetos/linkedIn_career_intelligence_lakehouse/warehouse/linkedin_career_intelligence.duckdb'), default_db_path=WindowsPath('C:/Projetos/linkedIn_career_intelligence_lakehouse/warehouse/linkedin_career_intelligence.duckdb'), demo_db_path=WindowsPath('C:/Projetos/linkedIn_career_intelligence_lakehouse/demo/linkedin_career_intelligence_demo.duckdb'), is_demo_db=False)

# %%
basic_dir = settings.export_dir("basic")
complete_dir = settings.export_dir("complete")

basic_files = sorted([p.relative_to(basic_dir).as_posix() for p in basic_dir.rglob("*.csv")])
complete_files = sorted([p.relative_to(complete_dir).as_posix() for p in complete_dir.rglob("*.csv")])

print(f"Basic export: {len(basic_files)} arquivos CSV")
print(f"Complete export: {len(complete_files)} arquivos CSV")
# Out:
# Basic export: 38 arquivos CSV
# Complete export: 53 arquivos CSV

# %%
pd.DataFrame({
    "basic_files": pd.Series(basic_files[:20]),
    "complete_files": pd.Series(complete_files[:20]),
})
# Out:
#                                           basic_files  \
# 0                                    Ad_Targeting.csv
# 1                                  Certifications.csv
# 2                                 Company Follows.csv
# 3                                     Connections.csv
# 4                                       Education.csv
# 5                                 Email Addresses.csv
# 6                       Endorsement_Received_Info.csv
# 7                                          Events.csv
# 8                                     Invitations.csv
# 9   Job Applicant Saved Screening Question Respons...
# 10  Job Applicant Saved Screening Question Respons...
# 11               Jobs/Job Applicant Saved Answers.csv
# 12                          Jobs/Job Applications.csv
# 13                    Jobs/Job Seeker Preferences.csv
# 14                                Jobs/Saved Jobs.csv
# 15                                      Languages.csv
# ...

# %%
connections_path = complete_dir / "Connections.csv"
connections_df = pd.read_csv(connections_path, skiprows=3, encoding="utf-8-sig")
connections_df.head()
# Out:
#   First Name Last Name                                                URL  \
# 0  Cristiana    Mattos       https://www.linkedin.com/in/cristiana-mattos
# 1     Denize     Sodré  https://www.linkedin.com/in/denize-sodre-educacao
# 2     Ingrid    Santos   https://www.linkedin.com/in/ingridsantosferreira
# 3    Rafaela    Medina       https://www.linkedin.com/in/rafaela-medina00
# 4   Fernanda     Sassi  https://www.linkedin.com/in/fernanda-sassi-380...
#
#                   Email Address  \
# 0                           NaN
# 1                           NaN
# 2  ingridsferreira322@gmail.com
# 3                           NaN
# 4                           NaN
#
#                                              Company  \
# 0                                   Accenture Brasil
# 1                                               FIAP
# 2    INDT - Instituto de Desenvolvimento Tecnológico
# 3                                             Delfia
# ...

# %%
connections_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9697 entries, 0 to 9696
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   First Name     9554 non-null   str
#  1   Last Name      9554 non-null   str
#  2   URL            9554 non-null   str
#  3   Email Address  506 non-null    str
#  4   Company        9456 non-null   str
#  5   Position       9460 non-null   str
#  6   Connected On   9697 non-null   str
# dtypes: str(7)
# memory usage: 1.6 MB
