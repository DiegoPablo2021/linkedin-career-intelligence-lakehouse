# %% [markdown]
# # 03 Validation Rules And Promotion
#
# Notebook reservado para validar regras antes de promover a logica para o pipeline oficial em Python e dbt.

# %% [markdown]
# ## Objetivo
#
# - registrar regras candidatas
# - validar amostras e impactos
# - documentar o que sera promovido para codigo versionado

# %%
from pathlib import Path

project_root = Path.cwd().resolve().parent
project_root
